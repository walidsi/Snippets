# %%
import requests
import json
import pandas as pd

# %%
df = pd.read_excel('Australian Post Codes.xlsx')
df.head()
# Out:
#       ID  Postcode                  Locality       State   Longitude  \
# 0   8525      4000                  BRISBANE  QUEENSLAND  153.022126
# 1   8526      4000  BRISBANE ADELAIDE STREET  QUEENSLAND  153.022126
# 2  21016      4000             BRISBANE CITY  QUEENSLAND  153.025123
# 3   8527      4000          BRISBANE CITY DC  QUEENSLAND  153.022126
# 4   8528      4000              BRISBANE GPO  QUEENSLAND  153.022126
#
#     Latitude       Category           Type      SA3               SA3 Name  \
# 0 -27.468391  Delivery Area  Delivery Area  30504.0  Brisbane Inner - West
# 1 -27.468391  Delivery Area  Delivery Area  30504.0  Brisbane Inner - West
# 2 -27.469771  Delivery Area  Delivery Area  30504.0  Brisbane Inner - West
# 3 -27.468391            NaN            NaN  30504.0  Brisbane Inner - West
# 4 -27.468391            NaN            NaN  30504.0  Brisbane Inner - West
#
#    ...  Long (Google) SA1 MAINCODE 2011 SA1 MAINCODE 2016 SA2 MAINCODE 2016  \
# ...

# %%
df.shape
# Out:
# (9381, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9381 entries, 0 to 9380
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 9381 non-null   int64
#  1   Postcode           9381 non-null   int64
#  2   Locality           9381 non-null   object
#  3   State              9381 non-null   object
#  4   Longitude          9380 non-null   float64
#  5   Latitude           9380 non-null   float64
#  6   Category           8546 non-null   object
#  7   Type               8546 non-null   object
#  8   SA3                9254 non-null   float64
#  9   SA3 Name           9254 non-null   object
#  10  SA4                9254 non-null   float64
#  11  SA4 Name           9254 non-null   object
#  12  Region             9378 non-null   object
#  13  Status             9359 non-null   object
#  14  Lat (Google)       9377 non-null   float64
#  15  Long (Google)      9377 non-null   float64
# ...

# %%
lat = (df['Latitude'].max() - df['Latitude'].min())/2 + df['Latitude'].min()
long = (df['Longitude'].max() - 75)/2 + 75

print((lat, long))
# Out:
# (-18.683087905, 117.0406085)

# %%
df['Longitude'].min()
# Out:
# 0.0

# %%
grouped = df.groupby('Postcode')

# %%
import folium

# %%
m = folium.Map(location=[lat, long], zoom_start=4)

for name, group in grouped:
    #print(name)
    
    marker = folium.CircleMarker(
            location = [group.Latitude.mean(), group.Longitude.mean()],
            radius = 5,
            fill_opacity = 0.8, color=None,
            fill_color = ('#274cc9'),
            popup = 'Number of people: {}'.format(group.shape[0]),
            tooltip = 'Postcode: {}, Lat:{}, Long:{}<br>Click for more info.'.format(name, group.Latitude.mean(), group.Longitude.mean())
            )

    marker.add_to(m) 

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
df2 = pd.read_excel('Apis Creek Road Central Qld - Seal it.xlsx')

# %%
df2.head()
# Out:
#    Respondent ID  Collector ID          Start Date            End Date  \
# 0            NaN           NaN                 NaT                 NaT
# 1   1.276189e+10   405376782.0 2021-06-22 12:50:11 2021-06-22 12:51:31
# 2   1.274999e+10   405376782.0 2021-06-17 12:19:26 2021-06-17 12:20:24
# 3   1.272650e+10   405376782.0 2021-06-09 07:18:40 2021-06-09 07:25:17
# 4   1.272438e+10   405376782.0 2021-06-08 18:28:07 2021-06-08 18:31:03
#
#    IP Address  Email Address  First Name  Last Name  Custom Data 1  \
# 0         NaN            NaN         NaN        NaN            NaN
# 1         NaN            NaN         NaN        NaN            NaN
# 2         NaN            NaN         NaN        NaN            NaN
# 3         NaN            NaN         NaN        NaN            NaN
# 4         NaN            NaN         NaN        NaN            NaN
#
#   DO YOU CURRENTLY USE THE UNSEALED APIS CREEK ROAD?  ... Unnamed: 17  \
# ...

# %%
df2['WHAT INDUSTRY DO YOU WORK IN?  (IF INVOLVED IN THE TRANSPORT OF GOODS, FOR WHAT INDUSTRY?)'].unique()
# Out:
# array(['Open-Ended Response', 'Agriculture', 'Cattle ', 'Livestock',
#        'Labour hire slavery at a coal mine.', 'Cattle station',
#        'Agriculture ', 'Agricultual ', 'Contractor ', 'Cattle',
#        ' Cattle and grain', 'Agriculture / kids to school ',
#        'Hospitality ', 'farming', nan, 'Use road for personal ', 'Rural',
#        'Farming, Heavy Haulage', 'Contract harvesting ', 'Grazing ',
#        'AGRICULTURAL', 'Retired', 'Primary Production', 'Ag',
#        'Beef Grazing', 'Grain transport ', 'Beef cattle and horses',
#        'Rural agency', 'Farmer', 'Ag Sales ',
#        'Road transport cartage of cattle,machinery,hay,gravel',
#        'Visiting ', 'Agricultural ', 'Real estate & retail ',
#        'Transport and Cattle', 'Agriculture & Feedlot', 'Communications',
#        'Ag ', 'Property Equipment Maintenance ', 'Mining ', 'Grazing',
#        'Molasses ', 'Transport of livestock ', 'Beef', 'Education ',
# ...

# %%
to_replace_list = ['Agriculture', 'Cattle ', 'Livestock', 'Agricultural', 'Farming ']

df2['WHAT INDUSTRY DO YOU WORK IN?  (IF INVOLVED IN THE TRANSPORT OF GOODS, FOR WHAT INDUSTRY?)'].replace(to_replace = to_replace_list, value = 'Agriculture', inplace=True)

# %%
df2['WHAT INDUSTRY DO YOU WORK IN?  (IF INVOLVED IN THE TRANSPORT OF GOODS, FOR WHAT INDUSTRY?)'].unique()
# Out:
# array(['Open-Ended Response', 'Agriculture',
#        'Labour hire slavery at a coal mine.', 'Cattle station',
#        'Agriculture ', 'Agricultual ', 'Contractor ', 'Cattle',
#        ' Cattle and grain', 'Agriculture / kids to school ',
#        'Hospitality ', 'farming', nan, 'Use road for personal ', 'Rural',
#        'Farming, Heavy Haulage', 'Contract harvesting ', 'Grazing ',
#        'AGRICULTURAL', 'Retired', 'Primary Production', 'Ag',
#        'Beef Grazing', 'Grain transport ', 'Beef cattle and horses',
#        'Rural agency', 'Farmer', 'Ag Sales ',
#        'Road transport cartage of cattle,machinery,hay,gravel',
#        'Visiting ', 'Agricultural ', 'Real estate & retail ',
#        'Transport and Cattle', 'Agriculture & Feedlot', 'Communications',
#        'Ag ', 'Property Equipment Maintenance ', 'Mining ', 'Grazing',
#        'Molasses ', 'Transport of livestock ', 'Beef', 'Education ',
#        'Agricultural Stockfeeds', 'Beef cattle', 'Farming',
# ...

# %%
unique_trips = df2['HOW MANY TRIPS/PART TRIPS PER MONTH (IN EITHER DIRECTION) ON AVERAGE?'].unique()
unique_trips
# Out:
# array(['Open-Ended Response', 4, '2 times a year', 1, '1 a year ',
#        'Use it daily ', 10, 'Once a month', 2, 3, 140, 0, 50, 60, '20-40',
#        6, 5, '15+', '10 plus', 40, '1-2', 'Nil', 20, nan, '10-15', 120, 8,
#        9, '6-8', 'Many', 28, 30, '4-8', 'Most days both ways ', 25,
#        'Used to do them regularly (once a week)', 15,
#        'A few times a year', 0.5, 12], dtype=object)

# %%
trips_dict = {}
trips_dict['4'] = 4
trips_dict['Once a month'] = 1
trips_dict['Use it daily '] = 30
trips_dict['Used to do them regularly (once a week)'] = 4

# %%
df2['HOW MANY TRIPS/PART TRIPS PER MONTH (IN EITHER DIRECTION) ON AVERAGE?'].replace(trips_dict, inplace=True)

# %%
df2['HOW MANY TRIPS/PART TRIPS PER MONTH (IN EITHER DIRECTION) ON AVERAGE?'].unique()
# Out:
# array(['Open-Ended Response', 4, '2 times a year', 1, '1 a year ', 30, 10,
#        2, 3, 140, 0, 50, 60, '20-40', 6, 5, '15+', '10 plus', 40, '1-2',
#        'Nil', 20, nan, '10-15', 120, 8, 9, '6-8', 'Many', 28, '4-8',
#        'Most days both ways ', 25, 15, 'A few times a year', 0.5, 12],
#       dtype=object)
